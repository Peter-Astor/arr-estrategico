# %% [markdown]
# # 02_analisis_principal.ipynb
# Análisis principales (ARR y modelos GEE)

# %%
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy.stats import wilcoxon

df = pd.read_csv("dataset_between.csv")
df.head()
# Out:
#   ID_Sujeto                 Origen_Form Identidad      Dilema  Orden_1  \
# 0   Suj_001  Respuestas de formulario 1       ABC  Bloque_CON        1
# 1   Suj_001  Respuestas de formulario 1       AEF  Bloque_CON        1
# 2   Suj_001  Respuestas de formulario 1       AJK  Bloque_CON        1
# 3   Suj_001  Respuestas de formulario 1         -    Atencion        1
# 4   Suj_001  Respuestas de formulario 1       AGH  Bloque_CON        1
#
#      Bloque  Orden_2 Respuesta  Mantiene  SDO_Score  ...  Promedio_DIST  \
# 0  Bloque_1        1  Opción 2         0        2.1  ...       0.666667
# 1  Bloque_5        2  Opción 2         0        2.1  ...       0.666667
# 2  Bloque_7        3  Opción 2         0        2.1  ...       0.666667
# 3  Bloque_0        1  Opción 3         0        2.1  ...       0.666667
# 4  Bloque_3        4  Opción 2         0        2.1  ...       0.666667
#
#    Delta_Mantiene  Delta_base  Tratamiento Mantiene_bin    NDC_c     SDO_c  \
# 0            -0.5         0.0          NaN            0 -0.30936 -0.036865
# 1            -0.5         0.0          NaN            0 -0.30936 -0.036865
# 2            -0.5         0.0          NaN            0 -0.30936 -0.036865
# 3            -0.5         0.0          NaN            0 -0.30936 -0.036865
# 4            -0.5         0.0          NaN            0 -0.30936 -0.036865
#
#       Gap  Gap0  Gap_pos
# 0     0.0     1      NaN
# 1  2000.0     0    350.0
# 2  2400.0     0    750.0
# 3     NaN     0      NaN
# 4     0.0     1      NaN
#
# [5 rows x 39 columns]

# %% [markdown]
# ## ARR basal por condición

# %%
means = df.groupby(["ID_Sujeto","Tratamiento"])["Mantiene_bin"].mean().reset_index()

for cond in ["DIST","SIN","CON"]:
    data = means[means.Tratamiento==cond]["Mantiene_bin"]
    stat,p = wilcoxon(data - 0.5)
    print(cond, "W=",stat,"p=",p)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16456\2538512109.py in <module>
#       3 for cond in ["DIST","SIN","CON"]:
#       4     data = means[means.Tratamiento==cond]["Mantiene_bin"]
# ----> 5     stat,p = wilcoxon(data - 0.5)
#       6     print(cond, "W=",stat,"p=",p)
#
# ~\anaconda3\lib\site-packages\scipy\stats\morestats.py in wilcoxon(x, y, zero_method, correction, alternative, mode)
#    3041     elif mode == "exact":
#    3042         # get frequencies cnt of the possible positive ranksums r_plus
# -> 3043         cnt = _get_wilcoxon_distr(count)
#    3044         # note: r_plus is int (ties not allowed), need int for slices below
#    3045         r_plus = int(r_plus)
#
# ~\anaconda3\lib\site-packages\scipy\stats\_hypotests.py in _get_wilcoxon_distr(n)
#     386
#     387     if cnt is None:
# --> 388         raise ValueError("The exact distribution of the Wilcoxon test "
#     389                          "statistic is not implemented for n={}".format(n))
#     390
#
# ValueError: The exact distribution of the Wilcoxon test statistic is not implemented for n=0

# %% [markdown]
# ## ARR por Gap

# %%
means_gap = df.groupby(["ID_Sujeto","Gap"])["Mantiene_bin"].mean().reset_index()

for g in sorted(means_gap.Gap.unique()):
    data = means_gap[means_gap.Gap==g]["Mantiene_bin"]
    stat,p = wilcoxon(data - 0.5)
    print("Gap",g,"W=",stat,"p=",p)
# Out:
# Gap 0.0 W= 2214.0 p= 0.015655844629049655
# Gap 1000.0 W= 5010.0 p= 0.00035658293910604085
# Gap 1200.0 W= 4342.0 p= 1.4932772631244806e-06
# Gap 2000.0 W= 3173.0 p= 2.8413713052243827e-12
# Gap 2400.0 W= 3006.0 p= 2.9685669975002543e-13

# %% [markdown]
# ## Modelo GEE 1 (Tratamiento)

# %%
model1 = smf.gee(
    "Mantiene_bin ~ C(Tratamiento)",
    groups="ID_Sujeto",
    data=df,
    family=sm.families.Binomial(),
    cov_struct=sm.cov_struct.Exchangeable()
).fit()

print(model1.summary())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16456\2360027256.py in <module>
# ----> 1 model1 = smf.gee(
#       2     "Mantiene_bin ~ C(Tratamiento)",
#       3     groups="ID_Sujeto",
#       4     data=df,
#       5     family=sm.families.Binomial(),
#
# ~\anaconda3\lib\site-packages\statsmodels\genmod\generalized_estimating_equations.py in from_formula(cls, formula, groups, data, subset, time, offset, exposure, *args, **kwargs)
#     757             del kwargs["family"]
#     758
# --> 759         model = super(GEE, cls).from_formula(formula, data=data, subset=subset,
#     760                                              groups=groups, time=time,
#     761                                              offset=offset,
#
# ~\anaconda3\lib\site-packages\statsmodels\base\model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     201             missing = 'raise'
#     202
# --> 203         tmp = handle_formula_data(data, None, formula, depth=eval_env,
#     204                                   missing=missing)
#     205         ((endog, exog), missing_idx, design_info) = tmp
#
# ~\anaconda3\lib\site-packages\statsmodels\formula\formulatools.py in handle_formula_data(Y, X, formula, depth, missing)
#      61     else:
#      62         if data_util._is_using_pandas(Y, None):
# ---> 63             result = dmatrices(formula, Y, depth, return_type='dataframe',
#      64                                NA_action=na_action)
#      65         else:
#
# ~\anaconda3\lib\site-packages\patsy\highlevel.py in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     315     """
#     316     eval_env = EvalEnvironment.capture(eval_env, reference=1)
# --> 317     (lhs, rhs) = _do_highlevel_design(
#     318         formula_like, data, eval_env, NA_action, return_type
#     319     )
#
# ~\anaconda3\lib\site-packages\patsy\highlevel.py in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     160         return iter([data])
#     161
# --> 162     design_infos = _try_incr_builders(
#     163         formula_like, data_iter_maker, eval_env, NA_action
#     164     )
#
# ~\anaconda3\lib\site-packages\patsy\highlevel.py in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      54     if isinstance(formula_like, ModelDesc):
#      55         assert isinstance(eval_env, EvalEnvironment)
# ---> 56         return design_matrix_builders(
#      57             [formula_like.lhs_termlist, formula_like.rhs_termlist],
#      58             data_iter_maker,
#
# ~\anaconda3\lib\site-packages\patsy\build.py in design_matrix_builders(termlists, data_iter_maker, eval_env, NA_action)
#     773     design_infos = []
#     774     for termlist in termlists:
# --> 775         term_to_subterm_infos = _make_subterm_infos(
#     776             termlist, num_column_counts, cat_levels_contrasts
#     777         )
#
# ~\anaconda3\lib\site-packages\patsy\build.py in _make_subterm_infos(terms, num_column_counts, cat_levels_contrasts)
#     678                         # This is where the default coding is set to
#     679                         # Treatment:
# --> 680                         coded = code_contrast_matrix(
#     681                             factor_coding[factor], levels, contrast, default=Treatment
#     682                         )
#
# ~\anaconda3\lib\site-packages\patsy\contrasts.py in code_contrast_matrix(intercept, levels, contrast, default)
#     640         return contrast.code_with_intercept(levels)
#     641     else:
# --> 642         return contrast.code_without_intercept(levels)
#
# ~\anaconda3\lib\site-packages\patsy\contrasts.py in code_without_intercept(self, levels)
#     183         else:
#     184             reference = _get_level(levels, self.reference)
# --> 185         eye = np.eye(len(levels) - 1)
#     186         contrasts = np.vstack(
#     187             (eye[:reference, :], np.zeros((1, len(levels) - 1)), eye[reference:, :])
#
# ~\anaconda3\lib\site-packages\numpy\lib\twodim_base.py in eye(N, M, k, dtype, order)
#     197     if M is None:
#     198         M = N
# --> 199     m = zeros((N, M), dtype=dtype, order=order)
#     200     if k >= M:
#     201         return m
#
# ValueError: negative dimensions are not allowed

# %% [markdown]
# ## Modelo GEE 2 (Tratamiento × Expectativa)

# %%
model2 = smf.gee(
    "Mantiene_bin ~ C(Tratamiento)*Expectativa_Activa",
    groups="ID_Sujeto",
    data=df,
    family=sm.families.Binomial(),
    cov_struct=sm.cov_struct.Exchangeable()
).fit()

print(model2.summary())

# %% [markdown]
# ## Modelo GEE 3 (Tratamiento × Expectativa × NDC)

# %%
model3 = smf.gee(
    "Mantiene_bin ~ C(Tratamiento)*Expectativa_Activa*NDC_c",
    groups="ID_Sujeto",
    data=df,
    family=sm.families.Binomial(),
    cov_struct=sm.cov_struct.Exchangeable()
).fit()

print(model3.summary())
