# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = df_long = pd.read_csv('df_long.csv')
df_resumen = pd.read_csv('Base_Resumen_Sujetos.csv')

# %%
# A. Datos Globales 
cols_gap = [c for c in df_resumen.columns if c.startswith('Promedio_Gap_')]
df_global = df_resumen.melt(id_vars='ID_Sujeto',
                                 value_vars=cols_gap, 
                                 var_name='Gap_Col',
                                 value_name='Valor'
                                 )

df_global['Gap'] = df_plot_global['Gap_Col'].str.extract('(\d+)').astype(int)

# B. Datos Primer Gap Absoluto (Manteniendo lógica de 1 obs por sujeto)
df_absoluto_primero = df.drop_duplicates(subset=['ID_Sujeto'], keep='first').copy()

# 2. Generación de Tablas
print("--- TABLA 1: PROMEDIO GLOBAL (SEM) ---")
t1 = df_global.groupby('Gap')['Valor'].agg(['count', 'mean', 'sem']).reset_index()
t1['Diff_vs_50%'] = (t1['mean'] - 0.5).round(3)
print(t1.round(3).to_string(index=False))

print("\n--- TABLA 2: PRIMER GAP ENCONTRADO (SEM) ---")
t2 = df_absoluto_primero.groupby('Gap_Size')['Mantiene'].agg(['count', 'mean', 'sem']).reset_index()
t2.rename(columns={'Gap_Size': 'Gap'}, inplace=True)
t2['Diff_vs_50%'] = (t2['mean'] - 0.5).round(3)
print(t2.round(3).to_string(index=False))

# 3. Visualización
sns.set_theme(style="whitegrid")
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6), sharey=True)

# Gráfico 1
sns.barplot(data=df_global, x='Gap', y='Valor', errorbar='se', capsize=.1, palette='mako', alpha=0.7, ax=ax1)
sns.stripplot(data=df_global, x='Gap', y='Valor', color='black', alpha=0.1, jitter=True, ax=ax1)
ax1.axhline(0.5, color='red', linestyle='--', linewidth=2, label='Azar (0.5)')
ax1.set_title('Global: Promedio por Sujeto', fontsize=13, fontweight='bold')
ax1.set(ylabel='Proporción (Mantiene)', xlabel='Gap Size')
ax1.legend()

# Gráfico 2
sns.barplot(data=df_absoluto_primero, x='Gap_Size', y='Mantiene', errorbar='se', capsize=.1, palette='magma', alpha=0.7, ax=ax2)
sns.stripplot(data=df_absoluto_primero, x='Gap_Size', y='Mantiene', color='black', alpha=0.1, jitter=True, ax=ax2)
ax2.axhline(0.5, color='red', linestyle='--', linewidth=2, label='Azar (0.5)')
ax2.set_title('Reacción Inicial (1er Bloque)', fontsize=13, fontweight='bold')
ax2.set(ylabel='', xlabel='Gap Size')
ax2.legend()

plt.tight_layout()
plt.show()
# Out:
# --- TABLA 1: PROMEDIO GLOBAL (SEM) ---
#  Gap  count  mean   sem  Diff_vs_50%
#    0    118 0.619 0.032        0.119
# 1000    118 0.331 0.035       -0.169
# 1200    118 0.305 0.034       -0.195
# 2000    118 0.229 0.032       -0.271
# 2400    118 0.178 0.028       -0.322
#
# --- TABLA 2: PRIMER GAP ENCONTRADO (SEM) ---
#  Gap  count  mean   sem  Diff_vs_50%
#    0     30 0.600 0.091        0.100
# 1000     29 0.345 0.090       -0.155
# 1200     31 0.387 0.089       -0.113
# 2400     28 0.143 0.067       -0.357

# %%
import pandas as pd

# 1. Cargar el archivo
df_long = pd.read_csv('df_long.csv')

# (Opcional) Asegurarte de que no hay duplicados antes de separar
df_long = df_long.drop_duplicates(subset=['ID_Sujeto', 'Orden_1', 'Orden_2'], keep='first').copy()

# 2. Creación de los 5 DataFrames separados por Gap_Size
df_0    = df_long[df_long['Gap_Size'] == 0].copy()
df_1000 = df_long[df_long['Gap_Size'] == 1000].copy()
df_1200 = df_long[df_long['Gap_Size'] == 1200].copy()
df_2000 = df_long[df_long['Gap_Size'] == 2000].copy()
df_2400 = df_long[df_long['Gap_Size'] == 2400].copy()

# 3. Verificación de contenido (Bloques y Cantidad de datos)
dataframes = {
    'df_0': df_0,
    'df_1000': df_1000,
    'df_1200': df_1200,
    'df_2000': df_2000,
    'df_2400': df_2400
}

print(f"{'Dataframe':<10} | {'Gap':<6} | {'N Filas':<8} | {'Bloques contenidos'}")
print("-" * 60)

for name, df in dataframes.items():
    gap_val = df['Gap_Size'].unique()[0] if not df.empty else 'Vacio'
    n_rows = len(df)
    # Obtenemos los bloques únicos y los ordenamos para ver cuáles son
    bloques = sorted(df['Bloque'].unique().tolist())
    
    print(f"{name:<10} | {gap_val:<6} | {n_rows:<8} | {bloques}")
# Out:
# Dataframe  | Gap    | N Filas  | Bloques contenidos
# ------------------------------------------------------------
# df_0       | 0      | 708      | ['Bloque_1', 'Bloque_3']
# df_1000    | 1000   | 354      | ['Bloque_9']
# df_1200    | 1200   | 354      | ['Bloque_11']
# df_2000    | 2000   | 354      | ['Bloque_5']
# df_2400    | 2400   | 354      | ['Bloque_7']
